# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1,2,3,4]
y = [2,4,6,8]

plt.plot(x,y)
plt.title('first graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
