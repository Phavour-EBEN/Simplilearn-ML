# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Phavour\Downloads\Personal Python-ML project\Simplilearn\Workspace\Feature Selection\Kobe Bryant - EDA_DF.csv")
data
# Out:
#            Column Name                                        Description  \
# 0          action_type                                       Type of Shot
# 1   combined_shot_type                            Type of Shot in Details
# 2        game_event_id  It is event id in a game. Basically it is the ...
# 3              game_id                              It is the game number
# 4                  lat  It is useless as it is Los Angeles even if the...
# 5                loc_x  If we take the basketball court picture, and t...
# 6                loc_y  If we take the basketball court picture, and t...
# 7                  lon  It is useless as it is Los Angeles even if the...
# 8    minutes_remaining                     Minutes remaining in the match
# 9               period  Like we have 2 halves in Football, basketball ...
# 10            playoffs     This is the final round where winner i decided
# 11              season                  Season on which the game was held
# ...

# %%
originalFeatures = data.columns

# %%
originalFeatures
# Out:
# Index(['Column Name', 'Description', 'Variable Type', 'Comments'], dtype='object')

# %%
print("Original Features count: ",len(originalFeatures))
# Out:
# Original Features count:  4
